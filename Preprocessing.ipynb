# %%
import pandas as pd
from TS import Series

# %%
path_50mV_0muMCa_0Que = './data/50mV_0muMCa_0Que/'
path_50mV_0muMCa_10Que = './data/50mV_0muMCa_10Que/'
path_50mV_0muMCa_100Que = './data/50mV_0muMCa_100Que/'
path_50mV_10muMCa_0Que = './data/50mV_10muMCa_0Que/'
path_50mV_10muMCa_10Que = './data/50mV_10muMCa_10Que/'
path_50mV_10muMCa_100Que = './data/50mV_10muMCa_100Que/'
path_50mV_100muMCa_0Que = './data/50mV_100muMCa_0Que/'
path_50mV_100muMCa_10Que = './data/50mV_100muMCa_10Que/'
path_50mV_100muMCa_100Que = './data/50mV_100muMCa_100Que/'

# %% [markdown]
# ### Data for classification whether querticin is present

# %%
ts_50mV_0muMCa_0Que_hbe43 = Series(path_50mV_0muMCa_0Que + 'hbe43.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe45 = Series(path_50mV_0muMCa_0Que + 'hbe45.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe46 = Series(path_50mV_0muMCa_0Que + 'hbe46.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe47 = Series(path_50mV_0muMCa_0Que + 'hbe47.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe49 = Series(path_50mV_0muMCa_0Que + 'hbe49.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe114 = Series(path_50mV_0muMCa_0Que + 'hbe114.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe118 = Series(path_50mV_0muMCa_0Que + 'hbe118.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe120 = Series(path_50mV_0muMCa_0Que + 'hbe120.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe125 = Series(path_50mV_0muMCa_0Que + 'hbe125.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe134 = Series(path_50mV_0muMCa_0Que + 'hbe134.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe135 = Series(path_50mV_0muMCa_0Que + 'hbe135.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe137 = Series(path_50mV_0muMCa_0Que + 'hbe137.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe138 = Series(path_50mV_0muMCa_0Que + 'hbe138.txt', 'NO_Que')
ts_50mV_0muMCa_0Que_hbe141 = Series(path_50mV_0muMCa_0Que + 'hbe141.txt', 'NO_Que')

ts_50mV_0muMCa_10Que_hbe50 = Series(path_50mV_0muMCa_10Que + 'hbe50.txt', 'Que')
ts_50mV_0muMCa_10Que_hbe51 = Series(path_50mV_0muMCa_10Que + 'hbe51.txt', 'Que')
ts_50mV_0muMCa_10Que_hbe52 = Series(path_50mV_0muMCa_10Que + 'hbe52.txt', 'Que')
ts_50mV_0muMCa_10Que_hbe54 = Series(path_50mV_0muMCa_10Que + 'hbe54.txt', 'Que')
ts_50mV_0muMCa_10Que_hbe56 = Series(path_50mV_0muMCa_10Que + 'hbe56.txt', 'Que')

ts_50mV_0muMCa_100Que_hbe115 = Series(path_50mV_0muMCa_100Que + 'hbe115.txt', 'Que')
ts_50mV_0muMCa_100Que_hbe117 = Series(path_50mV_0muMCa_100Que + 'hbe117.txt', 'Que')
ts_50mV_0muMCa_100Que_hbe123 = Series(path_50mV_0muMCa_100Que + 'hbe123.txt', 'Que')

ts_50mV_10muMCa_0Que_hbe59 = Series(path_50mV_10muMCa_0Que + 'hbe59.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe62 = Series(path_50mV_10muMCa_0Que + 'hbe62.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe150 = Series(path_50mV_10muMCa_0Que + 'hbe150.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe236 = Series(path_50mV_10muMCa_0Que + 'hbe236.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe238 = Series(path_50mV_10muMCa_0Que + 'hbe238.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe240 = Series(path_50mV_10muMCa_0Que + 'hbe240.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe249 = Series(path_50mV_10muMCa_0Que + 'hbe249.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe251 = Series(path_50mV_10muMCa_0Que + 'hbe251.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe253 = Series(path_50mV_10muMCa_0Que + 'hbe253.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe263 = Series(path_50mV_10muMCa_0Que + 'hbe263.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe265 = Series(path_50mV_10muMCa_0Que + 'hbe265.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe322 = Series(path_50mV_10muMCa_0Que + 'hbe322.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe370 = Series(path_50mV_10muMCa_0Que + 'hbe370.txt', 'NO_Que')
ts_50mV_10muMCa_0Que_hbe378 = Series(path_50mV_10muMCa_0Que + 'hbe378.txt', 'NO_Que')

ts_50mV_10muMCa_10Que_hbe58 = Series(path_50mV_10muMCa_10Que + 'hbe58.txt', 'Que')
ts_50mV_10muMCa_10Que_hbe374 = Series(path_50mV_10muMCa_10Que + 'hbe374.txt', 'Que')
ts_50mV_10muMCa_10Que_hbe379 = Series(path_50mV_10muMCa_10Que + 'hbe379.txt', 'Que')
ts_50mV_10muMCa_10Que_hbe381 = Series(path_50mV_10muMCa_10Que + 'hbe381.txt', 'Que')
ts_50mV_10muMCa_10Que_hbe397 = Series(path_50mV_10muMCa_10Que + 'hbe397.txt', 'Que')

ts_50mV_10muMCa_100Que_hbe241 = Series(path_50mV_10muMCa_100Que + 'hbe241.txt', 'Que')
ts_50mV_10muMCa_100Que_hbe242 = Series(path_50mV_10muMCa_100Que + 'hbe242.txt', 'Que')
ts_50mV_10muMCa_100Que_hbe256 = Series(path_50mV_10muMCa_100Que + 'hbe256.txt', 'Que')
ts_50mV_10muMCa_100Que_hbe258 = Series(path_50mV_10muMCa_100Que + 'hbe258.txt', 'Que')
ts_50mV_10muMCa_100Que_hbe260 = Series(path_50mV_10muMCa_100Que + 'hbe260.txt', 'Que')
ts_50mV_10muMCa_100Que_hbe268 = Series(path_50mV_10muMCa_100Que + 'hbe268.txt', 'Que')

ts_50mV_100muMCa_0Que_hbe82 = Series(path_50mV_100muMCa_0Que + 'hbe82.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe89 = Series(path_50mV_100muMCa_0Que + 'hbe89.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe98 = Series(path_50mV_100muMCa_0Que + 'hbe98.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe105 = Series(path_50mV_100muMCa_0Que + 'hbe105.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe110 = Series(path_50mV_100muMCa_0Que + 'hbe110.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe111 = Series(path_50mV_100muMCa_0Que + 'hbe111.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe221 = Series(path_50mV_100muMCa_0Que + 'hbe221.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe223 = Series(path_50mV_100muMCa_0Que + 'hbe223.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe227 = Series(path_50mV_100muMCa_0Que + 'hbe227.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe272 = Series(path_50mV_100muMCa_0Que + 'hbe272.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe274 = Series(path_50mV_100muMCa_0Que + 'hbe274.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe276 = Series(path_50mV_100muMCa_0Que + 'hbe276.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe284 = Series(path_50mV_100muMCa_0Que + 'hbe284.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe303 = Series(path_50mV_100muMCa_0Que + 'hbe303.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe305 = Series(path_50mV_100muMCa_0Que + 'hbe305.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe307 = Series(path_50mV_100muMCa_0Que + 'hbe307.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe309 = Series(path_50mV_100muMCa_0Que + 'hbe309.txt', 'NO_Que')
ts_50mV_100muMCa_0Que_hbe311 = Series(path_50mV_100muMCa_0Que + 'hbe311.txt', 'NO_Que')

ts_50mV_100muMCa_10Que_hbe83 = Series(path_50mV_100muMCa_10Que + 'hbe83.txt', 'Que')
ts_50mV_100muMCa_10Que_hbe85 = Series(path_50mV_100muMCa_10Que + 'hbe85.txt', 'Que')
ts_50mV_100muMCa_10Que_hbe109 = Series(path_50mV_100muMCa_10Que + 'hbe109.txt', 'Que')

ts_50mV_100muMCa_100Que_hbe277 = Series(path_50mV_100muMCa_100Que + 'hbe277.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe279 = Series(path_50mV_100muMCa_100Que + 'hbe279.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe281 = Series(path_50mV_100muMCa_100Que + 'hbe281.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe283 = Series(path_50mV_100muMCa_100Que + 'hbe283.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe290 = Series(path_50mV_100muMCa_100Que + 'hbe290.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe315 = Series(path_50mV_100muMCa_100Que + 'hbe315.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe317 = Series(path_50mV_100muMCa_100Que + 'hbe317.txt', 'Que')
ts_50mV_100muMCa_100Que_hbe319 = Series(path_50mV_100muMCa_100Que + 'hbe319.txt', 'Que')

# %%
df_ts_50mV_0muMCa_0Que_hbe43 = ts_50mV_0muMCa_0Que_hbe43.make_df()
df_ts_50mV_0muMCa_0Que_hbe45 = ts_50mV_0muMCa_0Que_hbe45.make_df()
df_ts_50mV_0muMCa_0Que_hbe46 = ts_50mV_0muMCa_0Que_hbe46.make_df()
df_ts_50mV_0muMCa_0Que_hbe47 = ts_50mV_0muMCa_0Que_hbe47.make_df()
df_ts_50mV_0muMCa_0Que_hbe49 = ts_50mV_0muMCa_0Que_hbe49.make_df()
df_ts_50mV_0muMCa_0Que_hbe114 = ts_50mV_0muMCa_0Que_hbe114.make_df()
df_ts_50mV_0muMCa_0Que_hbe118 = ts_50mV_0muMCa_0Que_hbe118.make_df()
df_ts_50mV_0muMCa_0Que_hbe120 = ts_50mV_0muMCa_0Que_hbe120.make_df()
df_ts_50mV_0muMCa_0Que_hbe125 = ts_50mV_0muMCa_0Que_hbe125.make_df()
df_ts_50mV_0muMCa_0Que_hbe134 = ts_50mV_0muMCa_0Que_hbe134.make_df()
df_ts_50mV_0muMCa_0Que_hbe135 = ts_50mV_0muMCa_0Que_hbe135.make_df()
df_ts_50mV_0muMCa_0Que_hbe137 = ts_50mV_0muMCa_0Que_hbe137.make_df()
df_ts_50mV_0muMCa_0Que_hbe138 = ts_50mV_0muMCa_0Que_hbe138.make_df()
df_ts_50mV_0muMCa_0Que_hbe141 = ts_50mV_0muMCa_0Que_hbe141.make_df()

df_ts_50mV_0muMCa_10Que_hbe50 = ts_50mV_0muMCa_10Que_hbe50.make_df()
df_ts_50mV_0muMCa_10Que_hbe51 = ts_50mV_0muMCa_10Que_hbe51.make_df()
df_ts_50mV_0muMCa_10Que_hbe52 = ts_50mV_0muMCa_10Que_hbe52.make_df()
df_ts_50mV_0muMCa_10Que_hbe54 = ts_50mV_0muMCa_10Que_hbe54.make_df()
df_ts_50mV_0muMCa_10Que_hbe56 = ts_50mV_0muMCa_10Que_hbe56.make_df()

df_ts_50mV_0muMCa_100Que_hbe115 = ts_50mV_0muMCa_100Que_hbe115.make_df()
df_ts_50mV_0muMCa_100Que_hbe117 = ts_50mV_0muMCa_100Que_hbe117.make_df()
df_ts_50mV_0muMCa_100Que_hbe123 = ts_50mV_0muMCa_100Que_hbe123.make_df()

df_ts_50mV_10muMCa_0Que_hbe59 = ts_50mV_10muMCa_0Que_hbe59.make_df()
df_ts_50mV_10muMCa_0Que_hbe62 = ts_50mV_10muMCa_0Que_hbe62.make_df()
df_ts_50mV_10muMCa_0Que_hbe150 = ts_50mV_10muMCa_0Que_hbe150.make_df()
df_ts_50mV_10muMCa_0Que_hbe236 = ts_50mV_10muMCa_0Que_hbe236.make_df()
df_ts_50mV_10muMCa_0Que_hbe238 = ts_50mV_10muMCa_0Que_hbe238.make_df()
df_ts_50mV_10muMCa_0Que_hbe240 = ts_50mV_10muMCa_0Que_hbe240.make_df()
df_ts_50mV_10muMCa_0Que_hbe249 = ts_50mV_10muMCa_0Que_hbe249.make_df()
df_ts_50mV_10muMCa_0Que_hbe251 = ts_50mV_10muMCa_0Que_hbe251.make_df()
df_ts_50mV_10muMCa_0Que_hbe253 = ts_50mV_10muMCa_0Que_hbe253.make_df()
df_ts_50mV_10muMCa_0Que_hbe263 = ts_50mV_10muMCa_0Que_hbe263.make_df()
df_ts_50mV_10muMCa_0Que_hbe265 = ts_50mV_10muMCa_0Que_hbe265.make_df()
df_ts_50mV_10muMCa_0Que_hbe322 = ts_50mV_10muMCa_0Que_hbe322.make_df()
df_ts_50mV_10muMCa_0Que_hbe370 = ts_50mV_10muMCa_0Que_hbe370.make_df()
df_ts_50mV_10muMCa_0Que_hbe378 = ts_50mV_10muMCa_0Que_hbe378.make_df()

df_ts_50mV_10muMCa_10Que_hbe58 = ts_50mV_10muMCa_10Que_hbe58.make_df()
df_ts_50mV_10muMCa_10Que_hbe374 = ts_50mV_10muMCa_10Que_hbe374.make_df()
df_ts_50mV_10muMCa_10Que_hbe379 = ts_50mV_10muMCa_10Que_hbe379.make_df()
df_ts_50mV_10muMCa_10Que_hbe381 = ts_50mV_10muMCa_10Que_hbe381.make_df()
df_ts_50mV_10muMCa_10Que_hbe397 = ts_50mV_10muMCa_10Que_hbe397.make_df()

df_ts_50mV_10muMCa_100Que_hbe241 = ts_50mV_10muMCa_100Que_hbe241.make_df()
df_ts_50mV_10muMCa_100Que_hbe242 = ts_50mV_10muMCa_100Que_hbe242.make_df()
df_ts_50mV_10muMCa_100Que_hbe256 = ts_50mV_10muMCa_100Que_hbe256.make_df()
df_ts_50mV_10muMCa_100Que_hbe258 = ts_50mV_10muMCa_100Que_hbe258.make_df()
df_ts_50mV_10muMCa_100Que_hbe260 = ts_50mV_10muMCa_100Que_hbe260.make_df()
df_ts_50mV_10muMCa_100Que_hbe268 = ts_50mV_10muMCa_100Que_hbe268.make_df()

df_ts_50mV_100muMCa_0Que_hbe82 = ts_50mV_100muMCa_0Que_hbe82.make_df()
df_ts_50mV_100muMCa_0Que_hbe89 = ts_50mV_100muMCa_0Que_hbe89.make_df()
df_ts_50mV_100muMCa_0Que_hbe98 = ts_50mV_100muMCa_0Que_hbe98.make_df()
df_ts_50mV_100muMCa_0Que_hbe105 = ts_50mV_100muMCa_0Que_hbe105.make_df()
df_ts_50mV_100muMCa_0Que_hbe110 = ts_50mV_100muMCa_0Que_hbe110.make_df()
df_ts_50mV_100muMCa_0Que_hbe111 = ts_50mV_100muMCa_0Que_hbe111.make_df()
df_ts_50mV_100muMCa_0Que_hbe221 = ts_50mV_100muMCa_0Que_hbe221.make_df()
df_ts_50mV_100muMCa_0Que_hbe223 = ts_50mV_100muMCa_0Que_hbe223.make_df()
df_ts_50mV_100muMCa_0Que_hbe227 = ts_50mV_100muMCa_0Que_hbe227.make_df()
df_ts_50mV_100muMCa_0Que_hbe272 = ts_50mV_100muMCa_0Que_hbe272.make_df()
df_ts_50mV_100muMCa_0Que_hbe274 = ts_50mV_100muMCa_0Que_hbe274.make_df()
df_ts_50mV_100muMCa_0Que_hbe276 = ts_50mV_100muMCa_0Que_hbe276.make_df()
df_ts_50mV_100muMCa_0Que_hbe284 = ts_50mV_100muMCa_0Que_hbe284.make_df()
df_ts_50mV_100muMCa_0Que_hbe303 = ts_50mV_100muMCa_0Que_hbe303.make_df()
df_ts_50mV_100muMCa_0Que_hbe305 = ts_50mV_100muMCa_0Que_hbe305.make_df()
df_ts_50mV_100muMCa_0Que_hbe307 = ts_50mV_100muMCa_0Que_hbe307.make_df()
df_ts_50mV_100muMCa_0Que_hbe309 = ts_50mV_100muMCa_0Que_hbe309.make_df()
df_ts_50mV_100muMCa_0Que_hbe311 = ts_50mV_100muMCa_0Que_hbe311.make_df()

df_ts_50mV_100muMCa_10Que_hbe83 = ts_50mV_100muMCa_10Que_hbe83.make_df()
df_ts_50mV_100muMCa_10Que_hbe85 = ts_50mV_100muMCa_10Que_hbe85.make_df()
df_ts_50mV_100muMCa_10Que_hbe109 = ts_50mV_100muMCa_10Que_hbe109.make_df()

df_ts_50mV_100muMCa_100Que_hbe277 = ts_50mV_100muMCa_100Que_hbe277.make_df()
df_ts_50mV_100muMCa_100Que_hbe279 = ts_50mV_100muMCa_100Que_hbe279.make_df()
df_ts_50mV_100muMCa_100Que_hbe281 = ts_50mV_100muMCa_100Que_hbe281.make_df()
df_ts_50mV_100muMCa_100Que_hbe283 = ts_50mV_100muMCa_100Que_hbe283.make_df()
df_ts_50mV_100muMCa_100Que_hbe290 = ts_50mV_100muMCa_100Que_hbe290.make_df()
df_ts_50mV_100muMCa_100Que_hbe315 = ts_50mV_100muMCa_100Que_hbe315.make_df()
df_ts_50mV_100muMCa_100Que_hbe317 = ts_50mV_100muMCa_100Que_hbe317.make_df()
df_ts_50mV_100muMCa_100Que_hbe319 = ts_50mV_100muMCa_100Que_hbe319.make_df()

# %%
df_is_que = pd.concat([
    df_ts_50mV_0muMCa_0Que_hbe43,
    df_ts_50mV_0muMCa_0Que_hbe45,
    df_ts_50mV_0muMCa_0Que_hbe46,
    df_ts_50mV_0muMCa_0Que_hbe47,
    df_ts_50mV_0muMCa_0Que_hbe49,
    df_ts_50mV_0muMCa_0Que_hbe114,
    df_ts_50mV_0muMCa_0Que_hbe118,
    df_ts_50mV_0muMCa_0Que_hbe120,
    df_ts_50mV_0muMCa_0Que_hbe125,
    df_ts_50mV_0muMCa_0Que_hbe134,
    df_ts_50mV_0muMCa_0Que_hbe135,
    df_ts_50mV_0muMCa_0Que_hbe137,
    df_ts_50mV_0muMCa_0Que_hbe138,
    df_ts_50mV_0muMCa_0Que_hbe141,
    df_ts_50mV_0muMCa_10Que_hbe50,
    df_ts_50mV_0muMCa_10Que_hbe51,
    df_ts_50mV_0muMCa_10Que_hbe52,
    df_ts_50mV_0muMCa_10Que_hbe54,
    df_ts_50mV_0muMCa_10Que_hbe56,
    df_ts_50mV_0muMCa_100Que_hbe115,
    df_ts_50mV_0muMCa_100Que_hbe117,
    df_ts_50mV_0muMCa_100Que_hbe123,
    df_ts_50mV_10muMCa_0Que_hbe59,
    df_ts_50mV_10muMCa_0Que_hbe62,
    df_ts_50mV_10muMCa_0Que_hbe150,
    df_ts_50mV_10muMCa_0Que_hbe236,
    df_ts_50mV_10muMCa_0Que_hbe238,
    df_ts_50mV_10muMCa_0Que_hbe240,
    df_ts_50mV_10muMCa_0Que_hbe249,
    df_ts_50mV_10muMCa_0Que_hbe251,
    df_ts_50mV_10muMCa_0Que_hbe253,
    df_ts_50mV_10muMCa_0Que_hbe263,
    df_ts_50mV_10muMCa_0Que_hbe265,
    df_ts_50mV_10muMCa_0Que_hbe322,
    df_ts_50mV_10muMCa_0Que_hbe370,
    df_ts_50mV_10muMCa_0Que_hbe378,
    df_ts_50mV_10muMCa_10Que_hbe58,
    df_ts_50mV_10muMCa_10Que_hbe374,
    df_ts_50mV_10muMCa_10Que_hbe379,
    df_ts_50mV_10muMCa_10Que_hbe381,
    df_ts_50mV_10muMCa_10Que_hbe397,
    df_ts_50mV_10muMCa_100Que_hbe241,
    df_ts_50mV_10muMCa_100Que_hbe242,
    df_ts_50mV_10muMCa_100Que_hbe256,
    df_ts_50mV_10muMCa_100Que_hbe258,
    df_ts_50mV_10muMCa_100Que_hbe260,
    df_ts_50mV_10muMCa_100Que_hbe268,
    df_ts_50mV_100muMCa_0Que_hbe82,
    df_ts_50mV_100muMCa_0Que_hbe89,
    df_ts_50mV_100muMCa_0Que_hbe98,
    df_ts_50mV_100muMCa_0Que_hbe105,
    df_ts_50mV_100muMCa_0Que_hbe110,
    df_ts_50mV_100muMCa_0Que_hbe111,
    df_ts_50mV_100muMCa_0Que_hbe221,
    df_ts_50mV_100muMCa_0Que_hbe223,
    df_ts_50mV_100muMCa_0Que_hbe227,
    df_ts_50mV_100muMCa_0Que_hbe272,
    df_ts_50mV_100muMCa_0Que_hbe274,
    df_ts_50mV_100muMCa_0Que_hbe276,
    df_ts_50mV_100muMCa_0Que_hbe284,
    df_ts_50mV_100muMCa_0Que_hbe303,
    df_ts_50mV_100muMCa_0Que_hbe305,
    df_ts_50mV_100muMCa_0Que_hbe307,
    df_ts_50mV_100muMCa_0Que_hbe309,
    df_ts_50mV_100muMCa_0Que_hbe311,
    df_ts_50mV_100muMCa_10Que_hbe83,
    df_ts_50mV_100muMCa_10Que_hbe85,
    df_ts_50mV_100muMCa_10Que_hbe109,
    df_ts_50mV_100muMCa_100Que_hbe277,
    df_ts_50mV_100muMCa_100Que_hbe279,
    df_ts_50mV_100muMCa_100Que_hbe281,
    df_ts_50mV_100muMCa_100Que_hbe283,
    df_ts_50mV_100muMCa_100Que_hbe290,
    df_ts_50mV_100muMCa_100Que_hbe315,
    df_ts_50mV_100muMCa_100Que_hbe317,
    df_ts_50mV_100muMCa_100Que_hbe319
    ])

# %%
df_is_que.dropna(inplace=True)

# %%
df_is_que.shape
# Out:
# (10700, 5001)

# %%
df_is_que.to_csv('./prepared_datasets/quercetin_classification.csv',
                 index=False)

# %% [markdown]
# ### Data for classifying querticin concentration

# %%
ts_50mV_0muMCa_0Que_hbe43_C = Series(path_50mV_0muMCa_0Que + 'hbe43.txt', 0)
ts_50mV_0muMCa_0Que_hbe45_C = Series(path_50mV_0muMCa_0Que + 'hbe45.txt', 0)
ts_50mV_0muMCa_0Que_hbe46_C = Series(path_50mV_0muMCa_0Que + 'hbe46.txt', 0)
ts_50mV_0muMCa_0Que_hbe47_C = Series(path_50mV_0muMCa_0Que + 'hbe47.txt', 0)
ts_50mV_0muMCa_0Que_hbe49_C = Series(path_50mV_0muMCa_0Que + 'hbe49.txt', 0)
ts_50mV_0muMCa_0Que_hbe114_C = Series(path_50mV_0muMCa_0Que + 'hbe114.txt', 0)
ts_50mV_0muMCa_0Que_hbe118_C = Series(path_50mV_0muMCa_0Que + 'hbe118.txt', 0)
ts_50mV_0muMCa_0Que_hbe120_C = Series(path_50mV_0muMCa_0Que + 'hbe120.txt', 0)
ts_50mV_0muMCa_0Que_hbe125_C = Series(path_50mV_0muMCa_0Que + 'hbe125.txt', 0)
ts_50mV_0muMCa_0Que_hbe134_C = Series(path_50mV_0muMCa_0Que + 'hbe134.txt', 0)
ts_50mV_0muMCa_0Que_hbe135_C = Series(path_50mV_0muMCa_0Que + 'hbe135.txt', 0)
ts_50mV_0muMCa_0Que_hbe137_C = Series(path_50mV_0muMCa_0Que + 'hbe137.txt', 0)
ts_50mV_0muMCa_0Que_hbe138_C = Series(path_50mV_0muMCa_0Que + 'hbe138.txt', 0)
ts_50mV_0muMCa_0Que_hbe141_C = Series(path_50mV_0muMCa_0Que + 'hbe141.txt', 0)

ts_50mV_0muMCa_10Que_hbe50_C = Series(path_50mV_0muMCa_10Que + 'hbe50.txt', 10)
ts_50mV_0muMCa_10Que_hbe51_C = Series(path_50mV_0muMCa_10Que + 'hbe51.txt', 10)
ts_50mV_0muMCa_10Que_hbe52_C = Series(path_50mV_0muMCa_10Que + 'hbe52.txt', 10)
ts_50mV_0muMCa_10Que_hbe54_C = Series(path_50mV_0muMCa_10Que + 'hbe54.txt', 10)
ts_50mV_0muMCa_10Que_hbe56_C = Series(path_50mV_0muMCa_10Que + 'hbe56.txt', 10)

ts_50mV_0muMCa_100Que_hbe115_C = Series(path_50mV_0muMCa_100Que + 'hbe115.txt', 100)
ts_50mV_0muMCa_100Que_hbe117_C = Series(path_50mV_0muMCa_100Que + 'hbe117.txt', 100)
ts_50mV_0muMCa_100Que_hbe123_C = Series(path_50mV_0muMCa_100Que + 'hbe123.txt', 100)

ts_50mV_10muMCa_0Que_hbe59_C = Series(path_50mV_10muMCa_0Que + 'hbe59.txt', 0)
ts_50mV_10muMCa_0Que_hbe62_C = Series(path_50mV_10muMCa_0Que + 'hbe62.txt', 0)
ts_50mV_10muMCa_0Que_hbe150_C = Series(path_50mV_10muMCa_0Que + 'hbe150.txt', 0)
ts_50mV_10muMCa_0Que_hbe236_C = Series(path_50mV_10muMCa_0Que + 'hbe236.txt', 0)
ts_50mV_10muMCa_0Que_hbe238_C = Series(path_50mV_10muMCa_0Que + 'hbe238.txt', 0)
ts_50mV_10muMCa_0Que_hbe240_C = Series(path_50mV_10muMCa_0Que + 'hbe240.txt', 0)
ts_50mV_10muMCa_0Que_hbe249_C = Series(path_50mV_10muMCa_0Que + 'hbe249.txt', 0)
ts_50mV_10muMCa_0Que_hbe251_C = Series(path_50mV_10muMCa_0Que + 'hbe251.txt', 0)
ts_50mV_10muMCa_0Que_hbe253_C = Series(path_50mV_10muMCa_0Que + 'hbe253.txt', 0)
ts_50mV_10muMCa_0Que_hbe263_C = Series(path_50mV_10muMCa_0Que + 'hbe263.txt', 0)
ts_50mV_10muMCa_0Que_hbe265_C = Series(path_50mV_10muMCa_0Que + 'hbe265.txt', 0)
ts_50mV_10muMCa_0Que_hbe322_C = Series(path_50mV_10muMCa_0Que + 'hbe322.txt', 0)
ts_50mV_10muMCa_0Que_hbe370_C = Series(path_50mV_10muMCa_0Que + 'hbe370.txt', 0)
ts_50mV_10muMCa_0Que_hbe378_C = Series(path_50mV_10muMCa_0Que + 'hbe378.txt', 0)

ts_50mV_10muMCa_10Que_hbe58_C = Series(path_50mV_10muMCa_10Que + 'hbe58.txt', 10)
ts_50mV_10muMCa_10Que_hbe374_C = Series(path_50mV_10muMCa_10Que + 'hbe374.txt', 10)
ts_50mV_10muMCa_10Que_hbe379_C = Series(path_50mV_10muMCa_10Que + 'hbe379.txt', 10)
ts_50mV_10muMCa_10Que_hbe381_C = Series(path_50mV_10muMCa_10Que + 'hbe381.txt', 10)
ts_50mV_10muMCa_10Que_hbe397_C = Series(path_50mV_10muMCa_10Que + 'hbe397.txt', 10)

ts_50mV_10muMCa_100Que_hbe241_C = Series(path_50mV_10muMCa_100Que + 'hbe241.txt', 100)
ts_50mV_10muMCa_100Que_hbe242_C = Series(path_50mV_10muMCa_100Que + 'hbe242.txt', 100)
ts_50mV_10muMCa_100Que_hbe256_C = Series(path_50mV_10muMCa_100Que + 'hbe256.txt', 100)
ts_50mV_10muMCa_100Que_hbe258_C = Series(path_50mV_10muMCa_100Que + 'hbe258.txt', 100)
ts_50mV_10muMCa_100Que_hbe260_C = Series(path_50mV_10muMCa_100Que + 'hbe260.txt', 100)
ts_50mV_10muMCa_100Que_hbe268_C = Series(path_50mV_10muMCa_100Que + 'hbe268.txt', 100)

ts_50mV_100muMCa_0Que_hbe82_C = Series(path_50mV_100muMCa_0Que + 'hbe82.txt', 0)
ts_50mV_100muMCa_0Que_hbe89_C = Series(path_50mV_100muMCa_0Que + 'hbe89.txt', 0)
ts_50mV_100muMCa_0Que_hbe98_C = Series(path_50mV_100muMCa_0Que + 'hbe98.txt', 0)
ts_50mV_100muMCa_0Que_hbe105_C = Series(path_50mV_100muMCa_0Que + 'hbe105.txt', 0)
ts_50mV_100muMCa_0Que_hbe110_C = Series(path_50mV_100muMCa_0Que + 'hbe110.txt', 0)
ts_50mV_100muMCa_0Que_hbe111_C = Series(path_50mV_100muMCa_0Que + 'hbe111.txt', 0)
ts_50mV_100muMCa_0Que_hbe221_C = Series(path_50mV_100muMCa_0Que + 'hbe221.txt', 0)
ts_50mV_100muMCa_0Que_hbe223_C = Series(path_50mV_100muMCa_0Que + 'hbe223.txt', 0)
ts_50mV_100muMCa_0Que_hbe227_C = Series(path_50mV_100muMCa_0Que + 'hbe227.txt', 0)
ts_50mV_100muMCa_0Que_hbe272_C = Series(path_50mV_100muMCa_0Que + 'hbe272.txt', 0)
ts_50mV_100muMCa_0Que_hbe274_C = Series(path_50mV_100muMCa_0Que + 'hbe274.txt', 0)
ts_50mV_100muMCa_0Que_hbe276_C = Series(path_50mV_100muMCa_0Que + 'hbe276.txt', 0)
ts_50mV_100muMCa_0Que_hbe284_C = Series(path_50mV_100muMCa_0Que + 'hbe284.txt', 0)
ts_50mV_100muMCa_0Que_hbe303_C = Series(path_50mV_100muMCa_0Que + 'hbe303.txt', 0)
ts_50mV_100muMCa_0Que_hbe305_C = Series(path_50mV_100muMCa_0Que + 'hbe305.txt', 0)
ts_50mV_100muMCa_0Que_hbe307_C = Series(path_50mV_100muMCa_0Que + 'hbe307.txt', 0)
ts_50mV_100muMCa_0Que_hbe309_C = Series(path_50mV_100muMCa_0Que + 'hbe309.txt', 0)
ts_50mV_100muMCa_0Que_hbe311_C = Series(path_50mV_100muMCa_0Que + 'hbe311.txt', 0)

ts_50mV_100muMCa_10Que_hbe83_C = Series(path_50mV_100muMCa_10Que + 'hbe83.txt', 10)
ts_50mV_100muMCa_10Que_hbe85_C = Series(path_50mV_100muMCa_10Que + 'hbe85.txt', 10)
ts_50mV_100muMCa_10Que_hbe109_C = Series(path_50mV_100muMCa_10Que + 'hbe109.txt', 10)

ts_50mV_100muMCa_100Que_hbe277_C = Series(path_50mV_100muMCa_100Que + 'hbe277.txt', 100)
ts_50mV_100muMCa_100Que_hbe279_C = Series(path_50mV_100muMCa_100Que + 'hbe279.txt', 100)
ts_50mV_100muMCa_100Que_hbe281_C = Series(path_50mV_100muMCa_100Que + 'hbe281.txt', 100)
ts_50mV_100muMCa_100Que_hbe283_C = Series(path_50mV_100muMCa_100Que + 'hbe283.txt', 100)
ts_50mV_100muMCa_100Que_hbe290_C = Series(path_50mV_100muMCa_100Que + 'hbe290.txt', 100)
ts_50mV_100muMCa_100Que_hbe315_C = Series(path_50mV_100muMCa_100Que + 'hbe315.txt', 100)
ts_50mV_100muMCa_100Que_hbe317_C = Series(path_50mV_100muMCa_100Que + 'hbe317.txt', 100)
ts_50mV_100muMCa_100Que_hbe319_C = Series(path_50mV_100muMCa_100Que + 'hbe319.txt', 100)

# %%
df_ts_50mV_0muMCa_0Que_hbe43_C = ts_50mV_0muMCa_0Que_hbe43_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe45_C = ts_50mV_0muMCa_0Que_hbe45_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe46_C = ts_50mV_0muMCa_0Que_hbe46_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe47_C = ts_50mV_0muMCa_0Que_hbe47_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe49_C = ts_50mV_0muMCa_0Que_hbe49_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe114_C = ts_50mV_0muMCa_0Que_hbe114_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe118_C = ts_50mV_0muMCa_0Que_hbe118_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe120_C = ts_50mV_0muMCa_0Que_hbe120_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe125_C = ts_50mV_0muMCa_0Que_hbe125_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe134_C = ts_50mV_0muMCa_0Que_hbe134_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe135_C = ts_50mV_0muMCa_0Que_hbe135_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe137_C = ts_50mV_0muMCa_0Que_hbe137_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe138_C = ts_50mV_0muMCa_0Que_hbe138_C.make_df()
df_ts_50mV_0muMCa_0Que_hbe141_C = ts_50mV_0muMCa_0Que_hbe141_C.make_df()

df_ts_50mV_0muMCa_10Que_hbe50_C = ts_50mV_0muMCa_10Que_hbe50_C.make_df()
df_ts_50mV_0muMCa_10Que_hbe51_C = ts_50mV_0muMCa_10Que_hbe51_C.make_df()
df_ts_50mV_0muMCa_10Que_hbe52_C = ts_50mV_0muMCa_10Que_hbe52_C.make_df()
df_ts_50mV_0muMCa_10Que_hbe54_C = ts_50mV_0muMCa_10Que_hbe54_C.make_df()
df_ts_50mV_0muMCa_10Que_hbe56_C = ts_50mV_0muMCa_10Que_hbe56_C.make_df()

df_ts_50mV_0muMCa_100Que_hbe115_C = ts_50mV_0muMCa_100Que_hbe115_C.make_df()
df_ts_50mV_0muMCa_100Que_hbe117_C = ts_50mV_0muMCa_100Que_hbe117_C.make_df()
df_ts_50mV_0muMCa_100Que_hbe123_C = ts_50mV_0muMCa_100Que_hbe123_C.make_df()

df_ts_50mV_10muMCa_0Que_hbe59_C = ts_50mV_10muMCa_0Que_hbe59_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe62_C = ts_50mV_10muMCa_0Que_hbe62_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe150_C = ts_50mV_10muMCa_0Que_hbe150_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe236_C = ts_50mV_10muMCa_0Que_hbe236_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe238_C = ts_50mV_10muMCa_0Que_hbe238_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe240_C = ts_50mV_10muMCa_0Que_hbe240_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe249_C = ts_50mV_10muMCa_0Que_hbe249_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe251_C = ts_50mV_10muMCa_0Que_hbe251_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe253_C = ts_50mV_10muMCa_0Que_hbe253_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe263_C = ts_50mV_10muMCa_0Que_hbe263_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe265_C = ts_50mV_10muMCa_0Que_hbe265_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe322_C = ts_50mV_10muMCa_0Que_hbe322_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe370_C = ts_50mV_10muMCa_0Que_hbe370_C.make_df()
df_ts_50mV_10muMCa_0Que_hbe378_C = ts_50mV_10muMCa_0Que_hbe378_C.make_df()

df_ts_50mV_10muMCa_10Que_hbe58_C = ts_50mV_10muMCa_10Que_hbe58_C.make_df()
df_ts_50mV_10muMCa_10Que_hbe374_C = ts_50mV_10muMCa_10Que_hbe374_C.make_df()
df_ts_50mV_10muMCa_10Que_hbe379_C = ts_50mV_10muMCa_10Que_hbe379_C.make_df()
df_ts_50mV_10muMCa_10Que_hbe381_C = ts_50mV_10muMCa_10Que_hbe381_C.make_df()
df_ts_50mV_10muMCa_10Que_hbe397_C = ts_50mV_10muMCa_10Que_hbe397_C.make_df()

df_ts_50mV_10muMCa_100Que_hbe241_C = ts_50mV_10muMCa_100Que_hbe241_C.make_df()
df_ts_50mV_10muMCa_100Que_hbe242_C = ts_50mV_10muMCa_100Que_hbe242_C.make_df()
df_ts_50mV_10muMCa_100Que_hbe256_C = ts_50mV_10muMCa_100Que_hbe256_C.make_df()
df_ts_50mV_10muMCa_100Que_hbe258_C = ts_50mV_10muMCa_100Que_hbe258_C.make_df()
df_ts_50mV_10muMCa_100Que_hbe260_C = ts_50mV_10muMCa_100Que_hbe260_C.make_df()
df_ts_50mV_10muMCa_100Que_hbe268_C = ts_50mV_10muMCa_100Que_hbe268_C.make_df()

df_ts_50mV_100muMCa_0Que_hbe82_C = ts_50mV_100muMCa_0Que_hbe82_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe89_C = ts_50mV_100muMCa_0Que_hbe89_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe98_C = ts_50mV_100muMCa_0Que_hbe98_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe105_C = ts_50mV_100muMCa_0Que_hbe105_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe110_C = ts_50mV_100muMCa_0Que_hbe110_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe111_C = ts_50mV_100muMCa_0Que_hbe111_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe221_C = ts_50mV_100muMCa_0Que_hbe221_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe223_C = ts_50mV_100muMCa_0Que_hbe223_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe227_C = ts_50mV_100muMCa_0Que_hbe227_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe272_C = ts_50mV_100muMCa_0Que_hbe272_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe274_C = ts_50mV_100muMCa_0Que_hbe274_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe276_C = ts_50mV_100muMCa_0Que_hbe276_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe284_C = ts_50mV_100muMCa_0Que_hbe284_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe303_C = ts_50mV_100muMCa_0Que_hbe303_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe305_C = ts_50mV_100muMCa_0Que_hbe305_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe307_C = ts_50mV_100muMCa_0Que_hbe307_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe309_C = ts_50mV_100muMCa_0Que_hbe309_C.make_df()
df_ts_50mV_100muMCa_0Que_hbe311_C = ts_50mV_100muMCa_0Que_hbe311_C.make_df()

df_ts_50mV_100muMCa_10Que_hbe83_C = ts_50mV_100muMCa_10Que_hbe83_C.make_df()
df_ts_50mV_100muMCa_10Que_hbe85_C = ts_50mV_100muMCa_10Que_hbe85_C.make_df()
df_ts_50mV_100muMCa_10Que_hbe109_C = ts_50mV_100muMCa_10Que_hbe109_C.make_df()

df_ts_50mV_100muMCa_100Que_hbe277_C = ts_50mV_100muMCa_100Que_hbe277_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe279_C = ts_50mV_100muMCa_100Que_hbe279_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe281_C = ts_50mV_100muMCa_100Que_hbe281_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe283_C = ts_50mV_100muMCa_100Que_hbe283_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe290_C = ts_50mV_100muMCa_100Que_hbe290_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe315_C = ts_50mV_100muMCa_100Que_hbe315_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe317_C = ts_50mV_100muMCa_100Que_hbe317_C.make_df()
df_ts_50mV_100muMCa_100Que_hbe319_C = ts_50mV_100muMCa_100Que_hbe319_C.make_df()

# %%
df_que_concentration = pd.concat([
    df_ts_50mV_0muMCa_0Que_hbe43_C,
    df_ts_50mV_0muMCa_0Que_hbe45_C,
    df_ts_50mV_0muMCa_0Que_hbe46_C,
    df_ts_50mV_0muMCa_0Que_hbe47_C,
    df_ts_50mV_0muMCa_0Que_hbe49_C,
    df_ts_50mV_0muMCa_0Que_hbe114_C,
    df_ts_50mV_0muMCa_0Que_hbe118_C,
    df_ts_50mV_0muMCa_0Que_hbe120_C,
    df_ts_50mV_0muMCa_0Que_hbe125_C,
    df_ts_50mV_0muMCa_0Que_hbe134_C,
    df_ts_50mV_0muMCa_0Que_hbe135_C,
    df_ts_50mV_0muMCa_0Que_hbe137_C,
    df_ts_50mV_0muMCa_0Que_hbe138_C,
    df_ts_50mV_0muMCa_0Que_hbe141_C,
    df_ts_50mV_0muMCa_10Que_hbe50_C,
    df_ts_50mV_0muMCa_10Que_hbe51_C,
    df_ts_50mV_0muMCa_10Que_hbe52_C,
    df_ts_50mV_0muMCa_10Que_hbe54_C,
    df_ts_50mV_0muMCa_10Que_hbe56_C,
    df_ts_50mV_0muMCa_100Que_hbe115_C,
    df_ts_50mV_0muMCa_100Que_hbe117_C,
    df_ts_50mV_0muMCa_100Que_hbe123_C,
    df_ts_50mV_10muMCa_0Que_hbe59_C,
    df_ts_50mV_10muMCa_0Que_hbe62_C,
    df_ts_50mV_10muMCa_0Que_hbe150_C,
    df_ts_50mV_10muMCa_0Que_hbe236_C,
    df_ts_50mV_10muMCa_0Que_hbe238_C,
    df_ts_50mV_10muMCa_0Que_hbe240_C,
    df_ts_50mV_10muMCa_0Que_hbe249_C,
    df_ts_50mV_10muMCa_0Que_hbe251_C,
    df_ts_50mV_10muMCa_0Que_hbe253_C,
    df_ts_50mV_10muMCa_0Que_hbe263_C,
    df_ts_50mV_10muMCa_0Que_hbe265_C,
    df_ts_50mV_10muMCa_0Que_hbe322_C,
    df_ts_50mV_10muMCa_0Que_hbe370_C,
    df_ts_50mV_10muMCa_0Que_hbe378_C,
    df_ts_50mV_10muMCa_10Que_hbe58_C,
    df_ts_50mV_10muMCa_10Que_hbe374_C,
    df_ts_50mV_10muMCa_10Que_hbe379_C,
    df_ts_50mV_10muMCa_10Que_hbe381_C,
    df_ts_50mV_10muMCa_10Que_hbe397_C,
    df_ts_50mV_10muMCa_100Que_hbe241_C,
    df_ts_50mV_10muMCa_100Que_hbe242_C,
    df_ts_50mV_10muMCa_100Que_hbe256_C,
    df_ts_50mV_10muMCa_100Que_hbe258_C,
    df_ts_50mV_10muMCa_100Que_hbe260_C,
    df_ts_50mV_10muMCa_100Que_hbe268_C,
    df_ts_50mV_100muMCa_0Que_hbe82_C,
    df_ts_50mV_100muMCa_0Que_hbe89_C,
    df_ts_50mV_100muMCa_0Que_hbe98_C,
    df_ts_50mV_100muMCa_0Que_hbe105_C,
    df_ts_50mV_100muMCa_0Que_hbe110_C,
    df_ts_50mV_100muMCa_0Que_hbe111_C,
    df_ts_50mV_100muMCa_0Que_hbe221_C,
    df_ts_50mV_100muMCa_0Que_hbe223_C,
    df_ts_50mV_100muMCa_0Que_hbe227_C,
    df_ts_50mV_100muMCa_0Que_hbe272_C,
    df_ts_50mV_100muMCa_0Que_hbe274_C,
    df_ts_50mV_100muMCa_0Que_hbe276_C,
    df_ts_50mV_100muMCa_0Que_hbe284_C,
    df_ts_50mV_100muMCa_0Que_hbe303_C,
    df_ts_50mV_100muMCa_0Que_hbe305_C,
    df_ts_50mV_100muMCa_0Que_hbe307_C,
    df_ts_50mV_100muMCa_0Que_hbe309_C,
    df_ts_50mV_100muMCa_0Que_hbe311_C,
    df_ts_50mV_100muMCa_10Que_hbe83_C,
    df_ts_50mV_100muMCa_10Que_hbe85_C,
    df_ts_50mV_100muMCa_10Que_hbe109_C,
    df_ts_50mV_100muMCa_100Que_hbe277_C,
    df_ts_50mV_100muMCa_100Que_hbe279_C,
    df_ts_50mV_100muMCa_100Que_hbe281_C,
    df_ts_50mV_100muMCa_100Que_hbe283_C,
    df_ts_50mV_100muMCa_100Que_hbe290_C,
    df_ts_50mV_100muMCa_100Que_hbe315_C,
    df_ts_50mV_100muMCa_100Que_hbe317_C,
    df_ts_50mV_100muMCa_100Que_hbe319_C
    ])

# %%
df_que_concentration.dropna(inplace=True)

# %%
df_que_concentration.shape
# Out:
# (10700, 5001)

# %%
df_que_concentration.to_csv('./prepared_datasets/quercetin_concentration_classification.csv',
                 index=False)
